# %%
import requests
import pandas as pd
import numpy as np

# %%
wages = pd.read_csv("./City_of_Seattle_Wage_Data_20260402.csv")

# %%
wages
# Out:
#                                  Department   Last Name  First Name  \
# 0                 Seattle Police Department      Aagard        Lori
# 1                        Seattle City Light    Aaltonen        Evan
# 2                  Seattle Public Utilities         Aar  Abdimallik
# 3      Seattle Department of Transportation        Abad     Abigail
# 4                            Human Services  Aba-Husain        Adam
# ...                                     ...         ...         ...
# 13859  Seattle Department of Transportation      Zuniga      Rafael
# 13860                Information Technology      Zuniga         Roy
# 13861              Seattle Public Utilities    Zurowski       Allan
# 13862             Seattle Police Department    Zwaschka      Andrew
# 13863              Seattle Public Utilities       Zweig        Will
#
#                                       Job Title Hourly Rate
# 0                                   Executive 4      $150.43
# ...
